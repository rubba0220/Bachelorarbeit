# %%
from astroquery.gaia import Gaia
import matplotlib.pyplot as plt
from os.path import isfile
from astropy.table import Table

# Plot-Formatierung
plt.rcParams['font.size'] = 24.0
plt.rcParams['font.family'] = 'sans-serif'
plt.rcParams['font.sans-serif'] = 'Arial'
plt.rcParams['font.weight'] = 'bold'
plt.rcParams['axes.labelsize'] = 'medium'
plt.rcParams['axes.labelweight'] = 'bold'
plt.rcParams['axes.linewidth'] = 1.2
plt.rcParams['lines.linewidth'] = 2.0

# %% [markdown]
# ### Skip the following if you dont want to query the database yourself

# %%
Gaia.login() # You might want to create your own account if you want to query the data yourself
# Out:
# INFO: Login to gaia TAP server [astroquery.gaia.core]
# INFO: OK [astroquery.utils.tap.core]
# INFO: Login to gaia data server [astroquery.gaia.core]
# INFO: OK [astroquery.utils.tap.core]

# %% [markdown]
# #### Printing Information about available tables and table contents

# %%
def print_available_gaiadr3_tables():    
    tables = Gaia.load_tables(only_names=True)
    for table in tables:
        name: str = table.get_qualified_name()
        if name.startswith("gaiadr3"):
            print(name)
print_available_gaiadr3_tables()
# Out:
# INFO: Retrieving tables... [astroquery.utils.tap.core]
# INFO: Parsing tables... [astroquery.utils.tap.core]
# INFO: Done. [astroquery.utils.tap.core]
# gaiadr3.gaiadr3.gaia_source
# gaiadr3.gaiadr3.gaia_source_lite
# gaiadr3.gaiadr3.astrophysical_parameters
# gaiadr3.gaiadr3.astrophysical_parameters_supp
# gaiadr3.gaiadr3.oa_neuron_information
# gaiadr3.gaiadr3.oa_neuron_xp_spectra
# gaiadr3.gaiadr3.total_galactic_extinction_map
# gaiadr3.gaiadr3.total_galactic_extinction_map_opt
# gaiadr3.gaiadr3.commanded_scan_law
# gaiadr3.gaiadr3.allwise_best_neighbour
# gaiadr3.gaiadr3.allwise_neighbourhood
# gaiadr3.gaiadr3.apassdr9_best_neighbour
# gaiadr3.gaiadr3.apassdr9_join
# gaiadr3.gaiadr3.apassdr9_neighbourhood
# gaiadr3.gaiadr3.dr2_neighbourhood
# gaiadr3.gaiadr3.gsc23_best_neighbour
# gaiadr3.gaiadr3.gsc23_join
# gaiadr3.gaiadr3.gsc23_neighbourhood
# gaiadr3.gaiadr3.hipparcos2_best_neighbour
# gaiadr3.gaiadr3.hipparcos2_neighbourhood
# gaiadr3.gaiadr3.panstarrs1_best_neighbour
# gaiadr3.gaiadr3.panstarrs1_join
# gaiadr3.gaiadr3.panstarrs1_neighbourhood
# gaiadr3.gaiadr3.ravedr5_best_neighbour
# gaiadr3.gaiadr3.ravedr5_join
# gaiadr3.gaiadr3.ravedr5_neighbourhood
# gaiadr3.gaiadr3.ravedr6_best_neighbour
# gaiadr3.gaiadr3.ravedr6_join
# gaiadr3.gaiadr3.ravedr6_neighbourhood
# gaiadr3.gaiadr3.sdssdr13_best_neighbour
# gaiadr3.gaiadr3.sdssdr13_join
# gaiadr3.gaiadr3.sdssdr13_neighbourhood
# gaiadr3.gaiadr3.skymapperdr2_best_neighbour
# gaiadr3.gaiadr3.skymapperdr2_join
# gaiadr3.gaiadr3.skymapperdr2_neighbourhood
# gaiadr3.gaiadr3.tmass_psc_xsc_best_neighbour
# gaiadr3.gaiadr3.tmass_psc_xsc_join
# gaiadr3.gaiadr3.tmass_psc_xsc_neighbourhood
# gaiadr3.gaiadr3.tycho2tdsc_merge_best_neighbour
# gaiadr3.gaiadr3.tycho2tdsc_merge_neighbourhood
# gaiadr3.gaiadr3.urat1_best_neighbour
# gaiadr3.gaiadr3.urat1_neighbourhood
# gaiadr3.gaiadr3.galaxy_candidates
# gaiadr3.gaiadr3.galaxy_catalogue_name
# gaiadr3.gaiadr3.qso_candidates
# gaiadr3.gaiadr3.qso_catalogue_name
# gaiadr3.gaiadr3.nss_acceleration_astro
# gaiadr3.gaiadr3.nss_non_linear_spectro
# gaiadr3.gaiadr3.nss_two_body_orbit
# gaiadr3.gaiadr3.nss_vim_fl
# gaiadr3.gaiadr3.binary_masses
# gaiadr3.gaiadr3.chemical_cartography
# gaiadr3.gaiadr3.gold_sample_carbon_stars
# gaiadr3.gaiadr3.gold_sample_fgkm_stars
# gaiadr3.gaiadr3.gold_sample_oba_stars
# gaiadr3.gaiadr3.gold_sample_solar_analogues
# gaiadr3.gaiadr3.gold_sample_spss
# gaiadr3.gaiadr3.gold_sample_ucd
# gaiadr3.gaiadr3.sso_orbits
# gaiadr3.gaiadr3.synthetic_photometry_gspc
# gaiadr3.gaiadr3.vari_spurious_signals
# gaiadr3.gaiadr3.agn_cross_id
# gaiadr3.gaiadr3.frame_rotator_source
# gaiadr3.gaiadr3.gaia_crf3_xm
# gaiadr3.gaiadr3.alerts_mixedin_sourceids
# gaiadr3.gaiadr3.science_alerts
# gaiadr3.gaiadr3.gaia_source_simulation
# gaiadr3.gaiadr3.gaia_universe_model
# gaiadr3.gaiadr3.sso_observation
# gaiadr3.gaiadr3.sso_reflectance_spectrum
# gaiadr3.gaiadr3.sso_source
# gaiadr3.gaiadr3.xp_summary
# gaiadr3.gaiadr3.vari_agn
# gaiadr3.gaiadr3.vari_cepheid
# gaiadr3.gaiadr3.vari_classifier_class_definition
# gaiadr3.gaiadr3.vari_classifier_definition
# gaiadr3.gaiadr3.vari_classifier_result
# gaiadr3.gaiadr3.vari_compact_companion
# gaiadr3.gaiadr3.vari_eclipsing_binary
# gaiadr3.gaiadr3.vari_epoch_radial_velocity
# gaiadr3.gaiadr3.vari_long_period_variable
# gaiadr3.gaiadr3.vari_microlensing
# gaiadr3.gaiadr3.vari_ms_oscillator
# gaiadr3.gaiadr3.vari_planetary_transit
# gaiadr3.gaiadr3.vari_planetary_transit_13june2022
# gaiadr3.gaiadr3.vari_rad_vel_statistics
# gaiadr3.gaiadr3.vari_rotation_modulation
# gaiadr3.gaiadr3.vari_rrlyrae
# gaiadr3.gaiadr3.vari_short_timescale
# gaiadr3.gaiadr3.vari_summary
# gaiadr3.gaiadr3.tycho2tdsc_merge

# %%
def print_columns(table = "gaiadr3.gaia_source"):
  gaiadr3_table = Gaia.load_table(table)
  print(f"{'NAME':<35}{'UNIT':<20}{'DESCRIPTION':<200}")
  for column in gaiadr3_table.columns:
    print(f"{str(column.name):<35}{str(column.unit):<20}{str(column.description):<200}")
print_columns()
# Out:
# NAME                               UNIT                DESCRIPTION
# solution_id                        None                Solution Identifier
# designation                        None                Unique source designation (unique across all Data Releases)
# source_id                          None                Unique source identifier (unique within a particular Data Release)
# random_index                       None                Random index for use when selecting subsets
# ref_epoch                          yr                  Reference epoch
# ra                                 deg                 Right ascension
# ra_error                           mas                 Standard error of right ascension
# dec                                deg                 Declination
# dec_error                          mas                 Standard error of declination
# parallax                           mas                 Parallax
# parallax_error                     mas                 Standard error of parallax
# parallax_over_error                None                Parallax divided by its standard error
# pm                                 mas.yr**-1          Total proper motion
# pmra                               mas.yr**-1          Proper motion in right ascension direction
# pmra_error                         mas.yr**-1          Standard error of proper motion in right ascension direction
# pmdec                              mas.yr**-1          Proper motion in declination direction
# pmdec_error                        mas.yr**-1          Standard error of proper motion in declination direction
# ra_dec_corr                        None                Correlation between right ascension and declination
# ra_parallax_corr                   None                Correlation between right ascension and parallax
# ra_pmra_corr                       None                Correlation between right ascension and proper motion in right ascension
# ra_pmdec_corr                      None                Correlation between right ascension and proper motion in declination
# dec_parallax_corr                  None                Correlation between declination and parallax
# dec_pmra_corr                      None                Correlation between declination and proper motion in right ascension
# dec_pmdec_corr                     None                Correlation between declination and proper motion in declination
# parallax_pmra_corr                 None                Correlation between parallax and proper motion in right ascension
# parallax_pmdec_corr                None                Correlation between parallax and proper motion in declination
# pmra_pmdec_corr                    None                Correlation between proper motion in right ascension and proper motion in declination
# astrometric_n_obs_al               None                Total number of observations in the along-scan (AL) direction
# astrometric_n_obs_ac               None                Total number of observations in the across-scan (AC) direction
# astrometric_n_good_obs_al          None                Number of good observations in the along-scan (AL) direction
# astrometric_n_bad_obs_al           None                Number of bad observations in the along-scan (AL) direction
# astrometric_gof_al                 None                Goodness of fit statistic of model wrt along-scan observations
# astrometric_chi2_al                None                AL chi-square value
# astrometric_excess_noise           mas                 Excess noise of the source
# astrometric_excess_noise_sig       None                Significance of excess noise
# astrometric_params_solved          None                Which parameters have been solved for?
# astrometric_primary_flag           None                Primary or seconday
# nu_eff_used_in_astrometry          um**-1              Effective wavenumber of the source used in the astrometric solution
# pseudocolour                       um**-1              Astrometrically estimated pseudocolour of the source
# pseudocolour_error                 um**-1              Standard error of the pseudocolour of the source
# ra_pseudocolour_corr               None                Correlation between right ascension and pseudocolour
# dec_pseudocolour_corr              None                Correlation between declination and pseudocolour
# parallax_pseudocolour_corr         None                Correlation between parallax and pseudocolour
# pmra_pseudocolour_corr             None                Correlation between proper motion in right asension and pseudocolour
# pmdec_pseudocolour_corr            None                Correlation between proper motion in declination and pseudocolour
# astrometric_matched_transits       None                Matched FOV transits used in the AGIS solution
# visibility_periods_used            None                Number of visibility periods used in Astrometric solution
# astrometric_sigma5d_max            mas                 The longest semi-major axis of the 5-d error ellipsoid
# matched_transits                   None                The number of transits matched to this source
# new_matched_transits               None                The number of transits newly incorporated into an existing source in the current cycle
# matched_transits_removed           None                The number of transits removed from an existing source in the current cycle
# ipd_gof_harmonic_amplitude         None                Amplitude of the IPD GoF versus position angle of scan
# ipd_gof_harmonic_phase             deg                 Phase of the IPD GoF versus position angle of scan
# ipd_frac_multi_peak                None                Percent of successful-IPD windows with more than one peak
# ipd_frac_odd_win                   None                Percent of transits with truncated windows or multiple gate
# ruwe                               None                Renormalised unit weight error
# scan_direction_strength_k1         None                Degree of concentration of scan directions across the source
# scan_direction_strength_k2         None                Degree of concentration of scan directions across the source
# scan_direction_strength_k3         None                Degree of concentration of scan directions across the source
# scan_direction_strength_k4         None                Degree of concentration of scan directions across the source
# scan_direction_mean_k1             deg                 Mean position angle of scan directions across the source
# scan_direction_mean_k2             deg                 Mean position angle of scan directions across the source
# scan_direction_mean_k3             deg                 Mean position angle of scan directions across the source
# scan_direction_mean_k4             deg                 Mean position angle of scan directions across the source
# duplicated_source                  None                Source with multiple source identifiers
# phot_g_n_obs                       None                Number of observations contributing to G photometry
# phot_g_mean_flux                   'electron'.s**-1    G-band mean flux
# phot_g_mean_flux_error             'electron'.s**-1    Error on G-band mean flux
# phot_g_mean_flux_over_error        None                G-band mean flux divided by its error
# phot_g_mean_mag                    mag                 G-band mean magnitude
# phot_bp_n_obs                      None                Number of observations contributing to BP photometry
# phot_bp_mean_flux                  'electron'.s**-1    Integrated BP mean flux
# phot_bp_mean_flux_error            'electron'.s**-1    Error on the integrated BP mean flux
# phot_bp_mean_flux_over_error       None                Integrated BP mean flux divided by its error
# phot_bp_mean_mag                   mag                 Integrated BP mean magnitude
# phot_rp_n_obs                      None                Number of observations contributing to RP photometry
# phot_rp_mean_flux                  'electron'.s**-1    Integrated RP mean flux
# phot_rp_mean_flux_error            'electron'.s**-1    Error on the integrated RP mean flux
# phot_rp_mean_flux_over_error       None                Integrated RP mean flux divided by its error
# phot_rp_mean_mag                   mag                 Integrated RP mean magnitude
# phot_bp_rp_excess_factor           None                BP/RP excess factor
# phot_bp_n_contaminated_transits    None                Number of BP contaminated transits
# phot_bp_n_blended_transits         None                Number of BP blended transits
# phot_rp_n_contaminated_transits    None                Number of RP contaminated transits
# phot_rp_n_blended_transits         None                Number of RP blended transits
# phot_proc_mode                     None                Photometry processing mode
# bp_rp                              mag                 BP - RP colour
# bp_g                               mag                 BP - G colour
# g_rp                               mag                 G - RP colour
# radial_velocity                    km.s**-1            Radial velocity
# radial_velocity_error              km.s**-1            Radial velocity error
# rv_method_used                     None                Method used to obtain the radial velocity
# rv_nb_transits                     None                Number of transits used to compute the radial velocity
# rv_nb_deblended_transits           None                Number of valid transits that have undergone deblending
# rv_visibility_periods_used         None                Number of visibility periods used to estimate the radial velocity
# rv_expected_sig_to_noise           None                Expected signal to noise ratio in the combination of the spectra used to obtain the radial velocity
# rv_renormalised_gof                None                Radial velocity renormalised goodness of fit
# rv_chisq_pvalue                    None                P-value for constancy based on a chi-squared criterion
# rv_time_duration                   d                   Time coverage of the radial velocity time series
# rv_amplitude_robust                km.s**-1            Total amplitude in the radial velocity time series after outlier removal
# rv_template_teff                   K                   Teff of the template used to compute the radial velocity
# rv_template_logg                   log(cm.s**-2)       Logg of the template used to compute the radial velocity
# rv_template_fe_h                   'dex'               [Fe/H] of the template used to compute the radial velocityy
# rv_atm_param_origin                None                Origin of the atmospheric parameters associated to the template
# vbroad                             km.s**-1            Spectral line broadening parameter
# vbroad_error                       km.s**-1            Uncertainty on the spectral line broadening
# vbroad_nb_transits                 None                Number of transits used to compute vbroad
# grvs_mag                           mag                 Integrated Grvs magnitude
# grvs_mag_error                     mag                 Grvs magnitude uncertainty
# grvs_mag_nb_transits               None                Number of transits used to compute Grvs
# rvs_spec_sig_to_noise              None                Signal to noise ratio in the mean RVS spectrum
# phot_variable_flag                 None                Photometric variability flag
# l                                  deg                 Galactic longitude
# b                                  deg                 Galactic latitude
# ecl_lon                            deg                 Ecliptic longitude
# ecl_lat                            deg                 Ecliptic latitude
# in_qso_candidates                  None                Flag indicating the availability of additional information in the QSO candidates table
# in_galaxy_candidates               None                Flag indicating the availability of additional information in the galaxy candidates table
# non_single_star                    None                Flag indicating the availability of additional information in the various Non-Single Star tables
# has_xp_continuous                  None                Flag indicating the availability of mean BP/RP spectrum in continuous representation for this source
# has_xp_sampled                     None                Flag indicating the availability of mean BP/RP spectrum in sampled form for this source
# has_rvs                            None                Flag indicating the availability of mean RVS spectrum for this source
# has_epoch_photometry               None                Flag indicating the availability of epoch photometry for this source
# has_epoch_rv                       None                Flag indicating the availability of epoch radial velocity for this source
# has_mcmc_gspphot                   None                Flag indicating the availability of GSP-Phot MCMC samples for this source
# has_mcmc_msc                       None                Flag indicating the availability of MSC MCMC samples for this source
# in_andromeda_survey                None                Flag indicating that the source is present in the Gaia Andromeda Photometric Survey (GAPS)
# classprob_dsc_combmod_quasar       None                Probability from DSC-Combmod of being a quasar (data used: BP/RP spectrum, photometry, astrometry)
# classprob_dsc_combmod_galaxy       None                Probability from DSC-Combmod of being a galaxy (data used: BP/RP spectrum, photometry, astrometry)
# classprob_dsc_combmod_star         None                Probability from DSC-Combmod of being a single star (but not a white dwarf) (data used: BP/RP spectrum, photometry, astrometry)
# teff_gspphot                       K                   Effective temperature from GSP-Phot Aeneas best library using BP/RP spectra
# teff_gspphot_lower                 K                   Lower confidence level (16%) of effective temperature from GSP-Phot Aeneas best library using BP/RP spectra
# teff_gspphot_upper                 K                   Upper confidence level (84%) of effective temperature from GSP-Phot Aeneas best library using BP/RP spectra
# logg_gspphot                       log(cm.s**-2)       Surface gravity from GSP-Phot Aeneas best library using BP/RP spectra
# logg_gspphot_lower                 log(cm.s**-2)       Lower confidence level (16%) of surface gravity from GSP-Phot Aeneas best library using BP/RP spectra
# logg_gspphot_upper                 log(cm.s**-2)       Upper confidence level (84%) of surface gravity from GSP-Phot Aeneas best library using BP/RP spectra
# mh_gspphot                         'dex'               Iron abundance from GSP-Phot Aeneas best library using BP/RP spectra
# mh_gspphot_lower                   'dex'               Lower confidence level (16%) of iron abundance from GSP-Phot Aeneas best library using BP/RP spectra
# mh_gspphot_upper                   'dex'               Upper confidence level (84%) of iron abundance from GSP-Phot Aeneas best library using BP/RP spectra
# distance_gspphot                   pc                  Distance from GSP-Phot Aeneas best library using BP/RP spectra
# distance_gspphot_lower             pc                  Lower confidence level (16%) of distance from GSP-Phot Aeneas best library using BP/RP spectra
# distance_gspphot_upper             pc                  Upper confidence level (84%) of distance from GSP-Phot Aeneas best library using BP/RP spectra
# azero_gspphot                      mag                 Monochromatic extinction $A_0$ at 547.7nm from GSP-Phot Aeneas best library using BP/RP spectra
# azero_gspphot_lower                mag                 Lower confidence level (16%) of monochromatic extinction $A_0$ at 547.7nm from GSP-Phot Aeneas best library using BP/RP spectra
# azero_gspphot_upper                mag                 Upper confidence level (84%) of monochromatic extinction $A_0$ at 547.7nm from GSP-Phot Aeneas best library using BP/RP spectra
# ag_gspphot                         mag                 Extinction in G band from GSP-Phot Aeneas best library using BP/RP spectra
# ag_gspphot_lower                   mag                 Lower confidence level (16%) of extinction in G band from GSP-Phot Aeneas best library using BP/RP spectra
# ag_gspphot_upper                   mag                 Upper confidence level (84%) of extinction in G band from GSP-Phot Aeneas best library using BP/RP spectra
# ebpminrp_gspphot                   mag                 Reddening $E(G_{\rm BP} - G_{\rm RP})$ from GSP-Phot Aeneas best library using BP/RP spectra
# ebpminrp_gspphot_lower             mag                 Lower confidence level (16%) of reddening  $E(G_{\rm BP} - G_{\rm RP})$ from GSP-Phot Aeneas best library using BP/RP spectra
# ebpminrp_gspphot_upper             mag                 Upper confidence level (84%) of reddening  $E(G_{\rm BP} - G_{\rm RP})$ from GSP-Phot Aeneas best library using BP/RP spectra
# libname_gspphot                    None                Name of library that achieves the highest mean log-posterior in MCMC samples and was used to derive GSP-Phot parameters in this table

# %% [markdown]
# ### Downloading Gaia Data

# %%
# TAP-query for downloading data
RERUN = True
filename = "C:/Users/Ruben/Documents/Bachelorarbeit/final_data_query.vot"
if (not isfile(filename)) or RERUN:
    query = """
    SELECT
        bp_rp,
        bp_g,
        g_rp,
        l, 
        b, 
        ra,
        ra_error,
        dec,
        dec_error,
        parallax, 
        parallax_error,
        pmra, 
        pmra_error,
        pmdec, 
        pmdec_error,
        phot_g_mean_mag, 
        nu_eff_used_in_astrometry,
        pseudocolour,
        ecl_lat,
        astrometric_params_solved,
        teff_gspphot,
        radial_velocity,
        radial_velocity_error
    FROM 
        gaiadr3.gaia_source AS gdr3
    WHERE
        parallax > 0.475
        AND (1000./parallax * COS(b*PI()/180)) < 220

    """

    # Perform TAP query
    job = Gaia.launch_job_async(query)  # This runs for >60min
    results = job.get_results()

    # Print the first few rows
    # print(results)

    # Save to file
    results.write(filename, format="votable", overwrite=True)
    print("Data download complete.")
else:
    print("Data file found. Skipping Gaia query.")
# Out:
# 500 Error 500:
# null
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[11], line 39
#       5 query = """
#       6 SELECT
#       7     bp_rp,
#    (...)
#      35
#      36 """
#      38 # Perform TAP query
# ---> 39 job = Gaia.launch_job_async(query)  # This runs for >60min
#      40 results = job.get_results()
#      42 # Print the first few rows
#      43 # print(results)
#      44
#      45 # Save to file
#
# File ~\AppData\Roaming\Python\Python311\site-packages\astroquery\gaia\core.py:1021, in GaiaClass.launch_job_async(self, query, name, output_file, output_format, verbose, dump_to_file, background, upload_resource, upload_table_name, autorun)
#     980 def launch_job_async(self, query, *, name=None, output_file=None,
#     981                      output_format="votable_gzip", verbose=False,
#     982                      dump_to_file=False, background=False,
#     983                      upload_resource=None, upload_table_name=None,
#     984                      autorun=True):
#     985     """Launches an asynchronous job
#     986
#     987     Parameters
#    (...)
#    1019     A Job object
#    1020     """
# -> 1021     return TapPlus.launch_job_async(self, query=query,
#    1022                                     name=name,
#    1023                                     output_file=output_file,
#    1024                                     output_format=output_format,
#    1025                                     verbose=verbose,
#    1026                                     dump_to_file=dump_to_file,
#    1027                                     background=background,
#    1028                                     upload_resource=upload_resource,
#    1029                                     upload_table_name=upload_table_name,
#    1030                                     autorun=autorun,
#    1031                                     format_with_results_compressed=('votable_gzip', 'fits', 'ecsv'))
#
# File ~\AppData\Roaming\Python\Python311\site-packages\astroquery\utils\tap\core.py:480, in Tap.launch_job_async(self, query, name, output_file, output_format, verbose, dump_to_file, background, upload_resource, upload_table_name, autorun, maxrec, format_with_results_compressed)
#     478                 job.save_results(verbose=verbose)
#     479             else:
# --> 480                 job.get_results()
#     481                 log.info("Query finished.")
#     482 return job
#
# File ~\AppData\Roaming\Python\Python311\site-packages\astroquery\utils\tap\model\job.py:242, in Job.get_results(self)
#     239     return None
#     240 else:
#     241     # async: result is in the server once the job is finished
# --> 242     self.__load_async_job_results()
#     243     return self.results
#
# File ~\AppData\Roaming\Python\Python311\site-packages\astroquery\utils\tap\model\job.py:348, in Job.__load_async_job_results(self, debug)
#     343     print(resultsResponse.getheaders())
#     345 resultsResponse = self.__handle_redirect_if_required(resultsResponse,
#     346                                                      verbose=debug)
#     347 isError = self.connHandler.\
# --> 348     check_launch_response_status(resultsResponse,
#     349                                  debug,
#     350                                  200)
#     351 self._phase = phase
#     352 if phase == 'ERROR':
#
# File ~\AppData\Roaming\Python\Python311\site-packages\astroquery\utils\tap\conn\tapconn.py:672, in TapConn.check_launch_response_status(self, response, debug, expected_response_status, raise_exception)
#     670     errMsg = taputils.get_http_response_error(response)
#     671     print(response.status, errMsg)
# --> 672     raise requests.exceptions.HTTPError(errMsg)
#     673 else:
#     674     return isError
#
# HTTPError: Error 500:
# null

# %% [markdown]
# ### End of Gaia query part
